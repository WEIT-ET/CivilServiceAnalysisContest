# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
cd weit
# Out:
# /content/drive/MyDrive/weit

# %%
ls
# Out:
# 10.22.ipynb                   데이터시각화10.14.ipynb  시각화파일/       정지선침범.xlsx
# LOCAL_PEOPLE_DONG_202309.csv  데이터시각화10.15.ipynb  신호위반.csv      중앙선침범.csv
# seoul/                        불법유턴.csv             신호위반.xlsx     중앙선침범.xlsx
# upload.ipynb                  불법유턴.xlsx            역주행.xlsx       지정차로위반.xlsx
# 꼬리물기.xlsx                 불법좌회전.csv           음주운전사고.csv  진로변경방법위반.xlsx
# 데이터시각화10.12.ipynb       불법좌회전.xlsx          정지선침범.csv    진로변경방빕위반.csv

# %%
from os.path import join

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/weit'
# replace with your Github username
GIT_USERNAME = "InbumS"
# definitely replace with your
GIT_TOKEN = "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"
# Replace with your github repository in this case we want
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "CivilServiceAnalysisContest"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure
print("PROJECT_PATH: ", PROJECT_PATH)

# In case we haven't created the folder already; we will create a folder in the project path
# !mkdir "{PROJECT_PATH}"

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/weit
# mkdir: cannot create directory ‘/content/drive/MyDrive/weit’: File exists
# GIT_PATH:  https://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@github.com/InbumS/CivilServiceAnalysisContest.git

# %%
# !git config --global user.email {sib0817@naver.com}
# !git config --global user.name {InbumS}

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/weit/.git/

# %%
# %cd "{PROJECT_PATH}"
# Out:
# /content/drive/MyDrive/weit

# %%
# !git add .

# %%
# !git commit -m "update: 2023-10-24"
# Out:
# [master (root-commit) 87b8bb0] update: 2023-10-24
#  33 files changed, 516688 insertions(+)
#  create mode 100644 10.22.ipynb
#  create mode 100644 LOCAL_PEOPLE_DONG_202309.csv
#  create mode 100644 seoul/Dong.geojson
#  create mode 100644 "seoul/\341\204\211\341\205\245\341\204\213\341\205\256\341\206\257\341\204\200\341\205\255\341\204\220\341\205\251\341\206\274\341\204\211\341\205\241\341\204\200\341\205\251\341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245"
#  create mode 100644 "seoul/\341\204\211\341\205\245\341\204\213\341\205\256\341\206\257\341\204\206\341\205\265\341\206\253\341\204\213\341\205\257\341\206\253\341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245.csv"
# ...

# %%
# !git remote add origin https://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@github.com/WEIT-ET/CivilServiceAnalysisContest.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git merge origin main --allow-unrelated-history
# Out:
# error: unknown option `allow-unrelated-history'
# usage: git merge [<options>] [<commit>...]
#    or: git merge --abort
#    or: git merge --continue
#
#     -n                    do not show a diffstat at the end of the merge
#     --stat                show a diffstat at the end of the merge
#     --summary             (synonym to --stat)
#     --log[=<n>]           add (at most <n>) entries from shortlog to merge commit message
#     --squash              create a single commit instead of doing a merge
#     --commit              perform a commit if the merge succeeds (default)
#     -e, --edit            edit message before committing
#     --cleanup <mode>      how to strip spaces and #comments from message
#     --ff                  allow fast-forward (default)
#     --ff-only             abort if fast-forward is not possible
#     --rerere-autoupdate   update the index with reused conflict resolution if possible
# ...

# %%
# !git remote set-head origin -a
# Out:
# origin/HEAD set to main

# %%
# !git fetch origin
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 689 bytes | 16.00 KiB/s, done.
# From https://github.com/WEIT-ET/CivilServiceAnalysisContest
#  * [new branch]      main       -> origin/main

# %%
# !git remote remove origin
